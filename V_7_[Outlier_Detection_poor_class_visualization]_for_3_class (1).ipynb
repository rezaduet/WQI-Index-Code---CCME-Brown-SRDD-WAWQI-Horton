# %% [markdown]
# # **Testing with previous dataset with 3 class of data**

# %%
from google.colab import drive
import pandas as pd
import glob
import os
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math
# Mount your Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/New Experimentation Code/Output.csv")
df.head()

df.shape
# Out:
# (29159, 24)

# %%
output_df = df
import matplotlib.pyplot as plt

# Sample data
data1 = output_df["CCME_Values"]
data2 = output_df["WAWQI_Values"]
data3 = output_df["Horton_values"]
data4 = output_df["Brown_values"]
data5 = output_df["SRDD_values"]

data = [data1, data2, data3, data4, data5]

# Define colors for the boxes
box_colors = ['blue', 'green', 'yellow', 'red', 'brown']

# Creating the box plot
plt.figure(figsize=(10, 6))
boxes = plt.boxplot(data, patch_artist=True)

# Assigning colors to each box
for box, color in zip(boxes['boxes'], box_colors):
    box.set(facecolor=color)

# Adding labels
plt.xlabel('WQI Models', fontsize=18)
plt.ylabel('WQI Value', fontsize=18)
plt.xticks([1, 2, 3, 4, 5], ['CCME', 'WAWQI', 'Horton', 'Brown', 'SRDD'], fontsize=22)
plt.yticks(fontsize=12)

# Setting y-axis range
plt.ylim(-5, 150)

# Setting the title and its font size
plt.title('Box Plot of Different WQI Models and Values', fontsize=18)

plt.tick_params(axis='x', labelsize=20)  # Increase the X-axis tick label size to 20
plt.tick_params(axis='y', labelsize=20)

# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
data1 = output_df["CCME_Values"]
data2 = output_df["WAWQI_Values"]
data3 = output_df["Horton_values"]
data4 = output_df["Brown_values"]
data5 = output_df["SRDD_values"]

data = [data1, data2, data3, data4, data5]

# Define colors for the boxes
box_colors = ['blue', 'green', 'yellow', 'red', 'brown']

# Creating the box plot
plt.figure(figsize=(10, 6))
boxes = plt.boxplot(data, patch_artist=True)

# Assigning colors to each box
for box, color in zip(boxes['boxes'], box_colors):
    box.set(facecolor=color)

# Adding labels
plt.xlabel('WQI Models', fontsize=18)
plt.ylabel('WQI Value', fontsize=18)
plt.xticks([1, 2, 3, 4, 5], ['CCME', 'WAWQI', 'Horton', 'Brown', 'SRDD'], fontsize=22)
plt.yticks(fontsize=16)  # Increase the y-axis label font size to 16

# Setting y-axis range
plt.ylim(-5, 110)

# Setting the title and its font size
plt.title('Box Plot of Different WQI Models and Values', fontsize=20)

# Make the median line bold
for median in boxes['medians']:
    median.set(color='black', linewidth=2)

# Displaying the plot
plt.show()

# %%
# output_df = df

# import pandas as pd

# # Assuming you have already loaded the dataset into a DataFrame named "output_df"

# # Display the initial number of rows
# print("Number of rows before dropping:", len(output_df))

# # Drop rows where specified columns contain "Unsuitable"
# output_df = output_df[~output_df["CCME_WQI"].str.contains("Unsuitable", na=False)]
# output_df = output_df[~output_df["WAWQI"].str.contains("Unsuitable", na=False)]
# output_df = output_df[~output_df["Horton WQI"].str.contains("Unsuitable", na=False)]
# output_df = output_df[~output_df["Brown WQI"].str.contains("Unsuitable", na=False)]
# output_df = output_df[~output_df["SRDD WQI"].str.contains("Unsuitable", na=False)]


# # Display the updated number of rows
# print("Number of rows after dropping:", len(output_df))

# %%
import matplotlib.pyplot as plt

# Select the desired columns from the dataset
selected_columns = ['Years', 'WAWQI_Values', 'Horton_values', 'Brown_values', 'CCME_Values', 'SRDD_values']
plot_data = output_df[selected_columns]

# Set the 'Years' column as the index
plot_data.set_index('Years', inplace=True)

# Plotting the data
fig, ax = plt.subplots()
plot_data.plot(ax=ax, linewidth=.2)  # Specify the linewidth as 2

# Adding labels and legend
ax.set_xlabel('Years')
ax.set_ylabel('Values')
ax.legend()

# Set y-axis limits from -10 to 250
ax.set_ylim(-10, 250)

# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
data1 = output_df["CCME_Values"]
data2 = output_df["WAWQI_Values"]
data3 = output_df["Horton_values"]
data4 = output_df["Brown_values"]
data5 = output_df["SRDD_values"]

data = [data1, data2, data3, data4, data5]

# Define colors for the boxes
box_colors = ['blue', 'green', 'yellow', 'red', 'brown']

# Creating the box plot
plt.figure(figsize=(10, 6))
boxes = plt.boxplot(data, patch_artist=True)

# Assigning colors to each box
for box, color in zip(boxes['boxes'], box_colors):
    box.set(facecolor=color)

# Adding labels
plt.xlabel('WQI Models', fontsize=16)
plt.ylabel('WQI Value', fontsize=16)
plt.xticks([1, 2, 3, 4, 5], ['CCME', 'WAWQI', 'Horton', 'Brown', 'SRDD'], fontsize=12)
plt.yticks(fontsize=12)

# Setting y-axis range
plt.ylim(-5, 110)

# Setting the title and its font size
plt.title('Box Plot of Different WQI Models and Values', fontsize=16)

# Displaying the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have already loaded the dataset 'output_df' into a DataFrame

# Columns to check for outliers
columns_to_check = ['WAWQI_Values', 'Horton_values', 'Brown_values', 'CCME_Values', 'SRDD_values']

# Function to detect outliers using the IQR (Interquartile Range) method
def detect_outliers(data):
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return (data < lower_bound) | (data > upper_bound)

outliers_counts = {}
for column in columns_to_check:
    outliers = detect_outliers(output_df[column])
    outliers_counts[column] = outliers.sum()

print("Number of outliers in each column:")
print(outliers_counts)

# Plotting box plots with colored boxes
plt.figure(figsize=(10, 6))

# Sample data
data1 = output_df["CCME_Values"]
data2 = output_df["WAWQI_Values"]
data3 = output_df["Horton_values"]
data4 = output_df["Brown_values"]
data5 = output_df["SRDD_values"]

data = [data1, data2, data3, data4, data5]

# Define colors for the boxes
box_colors = ['blue', 'green', 'yellow', 'red', 'brown']

# Creating the box plot
boxes = plt.boxplot(data, patch_artist=True)

# Assigning colors to each box
for box, color in zip(boxes['boxes'], box_colors):
    box.set(facecolor=color)

# Adding labels
plt.xlabel('WQI Models', fontsize=16)
plt.ylabel('WQI Value', fontsize=16)
plt.xticks([1, 2, 3, 4, 5], ['CCME', 'WAWQI', 'Horton', 'Brown', 'SRDD'], fontsize=12)
plt.yticks(fontsize=12)

# Setting y-axis range
plt.ylim(-5, 110)

# Setting the title and its font size
plt.title('Box Plot of Different WQI Models and Values', fontsize=16)

# Displaying the plot
plt.show()
# Out:
# Number of outliers in each column:
# {'WAWQI_Values': 5570, 'Horton_values': 12, 'Brown_values': 4, 'CCME_Values': 243, 'SRDD_values': 160}

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = output_df.iloc[:, -10:].corr()  # Select the last 11 columns for correlation
colormap = sns.diverging_palette(220, 10, as_cmap=True)

plt.figure(figsize=(9, 9))  # Figure size
heatmap = sns.heatmap(corr, cbar=True, square=True, annot=True, fmt='.2f',
                      annot_kws={'size': 22, 'weight': 'bold'},  # Increase font size and add bold weight
                      cmap=colormap, linewidths=0.1, linecolor='white')
plt.title('Correlation of WQI Models', y=1.05, size=20)

# Increase font size of x and y axis labels
heatmap.set_xticklabels(heatmap.get_xticklabels(), fontsize=18)
heatmap.set_yticklabels(heatmap.get_yticklabels(), fontsize=18)

plt.show()
# Out:
# <ipython-input-133-77927476da91>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = output_df.iloc[:, -10:].corr()  # Select the last 11 columns for correlation

# %%
new_df = output_df[(output_df["WAWQI"] == "Poor") & (output_df["Horton WQI"] == "Poor")]
new_df.head()
new_df.shape
# Out:
# (141, 24)

# %%
output_df = new_df

# import matplotlib.pyplot as plt

# # Sample data
# data1 = output_df["CCME_Values"]
# data2 = output_df["WAWQI_Values"]
# data3 = output_df["Horton_values"]
# data4 = output_df["Brown_values"]
# data5 = output_df["SRDD_values"]

# data = [data1, data2, data3, data4, data5]

# # Define colors for the boxes
# box_colors = ['blue', 'green', 'yellow', 'red', 'brown']

# # Creating the box plot
# plt.figure(figsize=(10, 6))
# boxes = plt.boxplot(data, patch_artist=True)

# # Assigning colors to each box
# for box, color in zip(boxes['boxes'], box_colors):
#     box.set(facecolor=color)

# # Adding labels
# plt.xlabel('Variables')
# plt.ylabel('WQI Value')
# plt.xticks([1, 2, 3, 4,5], ['CCME', 'WAWQI', 'Horton', 'Brown', 'SRDD'])

# # Setting y-axis range
# plt.ylim(0, 110)

# # Displaying the plot
# plt.show()


import matplotlib.pyplot as plt

# Sample data
data1 = output_df["CCME_Values"]
data2 = output_df["WAWQI_Values"]
data3 = output_df["Horton_values"]
data4 = output_df["Brown_values"]
data5 = output_df["SRDD_values"]

data = [data1, data2, data3, data4, data5]

# Define colors for the boxes
box_colors = ['blue', 'green', 'yellow', 'red', 'brown']

# Creating the box plot
plt.figure(figsize=(10, 6))
boxes = plt.boxplot(data, patch_artist=True)

# Assigning colors to each box
for box, color in zip(boxes['boxes'], box_colors):
    box.set(facecolor=color)

# Adding labels
plt.xlabel('WQI Models', fontsize=16)
plt.ylabel('WQI Value', fontsize=16)
plt.xticks([1, 2, 3, 4, 5], ['CCME', 'WAWQI', 'Horton', 'Brown', 'SRDD'], fontsize=12)
plt.yticks(fontsize=12)

# Setting y-axis range
plt.ylim(-5, 110)

# Setting the title and its font size
plt.title('Box Plot of Different WQI Models and Values', fontsize=16)

# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
data1 = output_df["CCME_Values"]
data2 = output_df["WAWQI_Values"]
data3 = output_df["Horton_values"]
data4 = output_df["Brown_values"]
data5 = output_df["SRDD_values"]

data = [data1, data2, data3, data4, data5]

# Define colors for the boxes
box_colors = ['blue', 'green', 'yellow', 'red', 'brown']

# Creating the box plot
plt.figure(figsize=(10, 6))
boxes = plt.boxplot(data, patch_artist=True)

# Assigning colors to each box
for box, color in zip(boxes['boxes'], box_colors):
    box.set(facecolor=color)

# Adding labels
plt.xlabel('Variables', fontsize=14)
plt.ylabel('WQI Value', fontsize=14)
plt.xticks([1, 2, 3, 4, 5], ['CCME', 'WAWQI', 'Horton', 'Brown', 'SRDD'], fontsize=12)
plt.yticks(fontsize=12)

# Setting y-axis range
plt.ylim(0, 110)

# Setting the title and its font size
plt.title('Box Plot of WQI Values', fontsize=16)

# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Select the desired columns from the dataset
selected_columns = ['Years', 'Horton_values', 'Brown_values', 'CCME_Values', 'SRDD_values', 'WAWQI_Values']
plot_data = new_df[selected_columns]

# Set the 'Years' column as the index
plot_data.set_index('Years', inplace=True)

# Increase the width of the figure
fig, ax = plt.subplots(figsize=(15, 8))  # Adjust the width value as needed

# Plotting the data
plot_data.plot(ax=ax)

# Adding labels and legend
ax.set_xlabel('Years', fontsize = 16)
ax.set_ylabel('WQI Values', fontsize = 16)
ax.legend()

# plt.xlabel('Variables', fontsize=14)
# plt.ylabel('WQI Value', fontsize=14)

# Set y-axis limits from -10 to 250
ax.set_ylim(-10, 150)
ax.tick_params(axis='x', labelsize=14)
ax.tick_params(axis='y', labelsize=14)
# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Select the desired columns from the dataset
selected_columns = ['Years', 'Horton_values', 'Brown_values', 'CCME_Values', 'SRDD_values', 'WAWQI_Values']
plot_data = new_df[selected_columns]

# Set the 'Years' column as the index
plot_data.set_index('Years', inplace=True)

# Increase the width of the figure
fig, ax = plt.subplots(figsize=(15, 8))  # Adjust the width value as needed

# Plotting the data with specified colors for each column
plot_data['Horton_values'].plot(ax=ax, color='green', label='Horton')
plot_data['Brown_values'].plot(ax=ax, color='red', label='Brown')
plot_data['CCME_Values'].plot(ax=ax, color='blue', label='CCME')
plot_data['SRDD_values'].plot(ax=ax, color='brown', label='SRDD')
plot_data['WAWQI_Values'].plot(ax=ax, color='black', label='WAWQI')

# Adding labels and legend
ax.set_xlabel('Years', fontsize=16)
ax.set_ylabel('WQI Values', fontsize=16)
ax.legend()

# Set y-axis limits from -10 to 250
ax.set_ylim(-10, 150)

# Increase font size for x-axis and y-axis tick labels
ax.tick_params(axis='x', labelsize=14)
ax.tick_params(axis='y', labelsize=14)

# Displaying the plot
plt.show()

# %%
wa_df = output_df[(output_df["WAWQI"] == "Poor")]
wa_df.shape
# Out:
# (141, 24)

# %%
import matplotlib.pyplot as plt

# Select the desired columns from the dataset
selected_columns = ['Years', 'Horton_values', 'Brown_values', 'CCME_Values', 'SRDD_values', 'WAWQI_Values']
plot_data = wa_df[selected_columns]

# Set the 'Years' column as the index
plot_data.set_index('Years', inplace=True)

# Increase the width of the figure
fig, ax = plt.subplots(figsize=(15, 8))  # Adjust the width value as needed

# Plotting the data
plot_data.plot(ax=ax)

# Adding labels and legend
ax.set_xlabel('Years')
ax.set_ylabel('Values')
ax.legend()

# Set y-axis limits from -10 to 250
ax.set_ylim(-10, 150)

# Displaying the plot
plt.show()

# %%
horton_df = output_df[ (output_df["Horton WQI"] == "Poor")]

# wa_df = new_df = output_df[(output_df["WAWQI"] == "Poor")]
horton_df.shape
# Out:
# (141, 24)

# %%
import matplotlib.pyplot as plt

# Select the desired columns from the dataset
selected_columns = ['Years', 'Horton_values', 'Brown_values', 'CCME_Values', 'SRDD_values', 'WAWQI_Values']
plot_data = horton_df[selected_columns]

# Set the 'Years' column as the index
plot_data.set_index('Years', inplace=True)

# Increase the width of the figure
fig, ax = plt.subplots(figsize=(15, 8))  # Adjust the width value as needed

# Plotting the data
plot_data.plot(ax=ax)

# Adding labels and legend
ax.set_xlabel('Years')
ax.set_ylabel('Values')
ax.legend()

# Set y-axis limits from -10 to 250
ax.set_ylim(-10, 150)

# Displaying the plot
plt.show()

# %%
output_df = wa_df

import matplotlib.pyplot as plt

df1 = output_df["CCME_Values"]
df2 = output_df["WAWQI_Values"]
df3 = output_df["Horton_values"]
df4 = output_df["Brown_values"]
df5 = output_df["SRDD_values"]

dot_size = 2  # Specify the size of the dots

plt.figure(figsize=(15, 8))
plt.scatter(df1.index, df1, s=dot_size, color='blue', label='CCME Values')
plt.scatter(df3.index, df3, s=dot_size, color='green', label='Horton_values Values')
plt.scatter(df4.index, df4, s=dot_size, color='red', label='Brown_values Values')
plt.scatter(df5.index, df5, s=dot_size, color='brown', label='SRDD Values')
plt.scatter(df2.index, df2, s=dot_size, color='black', label='WAWQI Values')

# Set the font size for the X-axis and Y-axis labels
plt.xlabel('Days', fontsize=14)
plt.ylabel('WQI Value', fontsize=14)

plt.legend()

plt.ylim(0, 110)  # Set the y-axis range from 0 to 120

# Increase the size of tick labels on the X-axis and Y-axis scales
plt.tick_params(axis='x', labelsize=14)
plt.tick_params(axis='y', labelsize=14)

plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have already defined the df1, df2, df3, df4, and df5 DataFrames.

dot_size = 35  # Specify the size of the dots

plt.figure(figsize=(15, 8))
plt.scatter(df1.index, df1, s=dot_size, color='blue', label='CCME')
plt.scatter(df4.index, df4, s=dot_size, color='red', label='Brown')
plt.scatter(df5.index, df5, s=dot_size, color='brown', label='SRDD')
plt.scatter(df2.index, df2, s=dot_size, color='black', label='WAWQI')
plt.scatter(df3.index, df3, s=dot_size, color='green', label='Horton')

# Set the font size for the X-axis and Y-axis labels
plt.xlabel('Days', fontsize=18)
plt.ylabel('WQI Value', fontsize=18)

# Set the font size for the legend
plt.legend(prop={'size': 18})  # Increase the legend font size to 16

plt.ylim(0, 110)  # Set the y-axis range from 0 to 120

# Increase the size of tick labels on the X-axis and Y-axis scales
plt.tick_params(axis='x', labelsize=22)
plt.tick_params(axis='y', labelsize=22)

plt.show()

# %%
output_df = new_df
import matplotlib.pyplot as plt

df1 = output_df["CCME_Values"]
df2 = output_df["WAWQI_Values"]
df3 = output_df["Horton_values"]
df4 = output_df["Brown_values"]
df5 = output_df["SRDD_values"]

dot_size = 2  # Specify the size of the dots

plt.figure(figsize=(15, 8))
plt.scatter(df1.index, df1, s=dot_size, color='blue', label='CCME Values')
plt.scatter(df4.index, df4, s=dot_size, color='red', label='Brown_values Values')
plt.scatter(df5.index, df5, s=dot_size, color='brown', label='SRDD Values')
plt.scatter(df2.index, df2, s=dot_size, color='black', label='WAWQI Values')
plt.scatter(df3.index, df3, s=dot_size, color='green', label='Horton_values Values')

# Set the font size for the X-axis and Y-axis labels
plt.xlabel('Days', fontsize=14)
plt.ylabel('WQI Value', fontsize=14)

plt.legend()

plt.ylim(0, 110)  # Set the y-axis range from 0 to 120

# Increase the size of tick labels on the X-axis and Y-axis scales
plt.tick_params(axis='x', labelsize=14)
plt.tick_params(axis='y', labelsize=14)

plt.show()
